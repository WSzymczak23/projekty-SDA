# %% [markdown]
# <a href="https://colab.research.google.com/github/WSzymczak23/projekty-SDA/blob/main/31_01_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import seaborn as sns
from IPython.display import display

# %%
wine = pd.read_csv('/content/sample_data/wine.csv')

# %%
sns.lmplot(x='Alcohol', y='Magnesium', data=wine,fit_reg=False, hue='Class')
plt.ylim(40,140)
plt.xlim(11,15)
# Out:
# (11.0, 15.0)

# %%
wine.columns
# Out:
# Index(['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium',
#        'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline', 'Class'],
#       dtype='object')

# %%
g = sns.boxplot(data=wine.iloc[:,5:-2])
g.xaxis.set_tick_params(rotation=90)

# %%
#sns.set_style('whitegrid')
sns.violinplot(x='Class', y='Alcohol', data=wine)

# %%
sns.swarmplot(x='Class', y='Alcohol', data=wine)

# %%
plt.figure(figsize=(12,8))
sns.violinplot(x='Class', y='Alcohol', data=wine, inner=None)
sns.swarmplot(x='Class', y='Alcohol', data=wine, color='r', alpha = 0.7)

# %%
wine.head()
# Out:
#    Alcohol  Malic acid   Ash  ...  OD280/OD315 of diluted wines  Proline  Class
# 0    14.23        1.71  2.43  ...                          3.92     1065    one
# 1    13.20        1.78  2.14  ...                          3.40     1050    one
# 2    13.16        2.36  2.67  ...                          3.17     1185    one
# 3    14.37        1.95  2.50  ...                          3.45     1480    one
# 4    13.24        2.59  2.87  ...                          2.93      735    one
#
# [5 rows x 14 columns]

# %%
melted_df = pd.melt(wine.iloc[:,5:], id_vars='Class', var_name='Stats')
melted_df.columns
# Out:
# Index(['Class', 'Stats', 'value'], dtype='object')

# %%
plt.figure()
sns.swarmplot(x='Stats', y='value', data=melted_df)
plt.ylim(0,14)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 96.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 29.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# (0.0, 14.0)

# %%
corr = wine.corr()

# %%
corr
# Out:
#                                Alcohol  ...   Proline
# Alcohol                       1.000000  ...  0.643720
# Malic acid                    0.094397  ... -0.192011
# Ash                           0.211545  ...  0.223626
# Alcalinity of ash            -0.310235  ... -0.440597
# Magnesium                     0.270798  ...  0.393351
# Total phenols                 0.289101  ...  0.498115
# Flavanoids                    0.236815  ...  0.494193
# Nonflavanoid phenols         -0.155929  ... -0.311385
# Proanthocyanins               0.136698  ...  0.330417
# Color intensity               0.546364  ...  0.316100
# Hue                          -0.071747  ...  0.236183
# OD280/OD315 of diluted wines  0.072343  ...  0.312761
# Proline                       0.643720  ...  1.000000
#
# [13 rows x 13 columns]

# %%
sns.heatmap(corr)

# %%
sns.displot(wine.Alcohol)

# %%
sns.kdeplot(wine.Alcohol, wine.Magnesium)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.heatmap()

# %%
import plotnine
from plotnine import *
from plotnine.data import mpg
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
(ggplot(mpg)
+aes(x='class')
+geom_bar(size=20)
)
# Out:
# /usr/local/lib/python3.6/dist-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (-9223363248753670200)>

# %%
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
timesData=pd.read_csv('/content/sample_data/timesData.csv')

# %%
timesData.head()
# Out:
#   world_rank                        university_name  ... female_male_ratio  year
# 0          1                     Harvard University  ...               NaN  2011
# 1          2     California Institute of Technology  ...           33 : 67  2011
# 2          3  Massachusetts Institute of Technology  ...           37 : 63  2011
# 3          4                    Stanford University  ...           42 : 58  2011
# 4          5                   Princeton University  ...           45 : 55  2011
#
# [5 rows x 14 columns]

# %%
df = timesData.iloc[:100,:]

# %%
trace1 = go.Scatter(
    x = df.world_rank,
    y = df.citations,
    mode = 'lines',
    name = 'Cytowania',
    marker = dict(color = 'rgba(16, 112, 2, 0.8)'),
    text = df.university_name
)

trace2 = go.Scatter(
    x=df.world_rank,
    y = df.teaching,
    mode = 'lines+markers',
  name = 'Poziom nauki',
  marker = dict(color = 'rgba(80, 26, 80, 0.8)'),
  text = df.university_name
)

data = [trace1, trace2]

layout = dict(title = 'Poziom nauczania i cytowania',
              xaxis = dict (title='Ranking swiatowy', ticklen =5, zeroline = False))
fig=dict(data=data, layout=layout)
iplot (fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="28fd1d0b-3df8-4888-80be-eed9b1906d11" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("28fd1d0b-3df8-4888-80be-eed9b1906d11")) {
#                     Plotly.newPlot(
#                         '28fd1d0b-3df8-4888-80be-eed9b1906d11',
# ...

# %%
df2014 = timesData[timesData.year==2014].iloc[:100,:]
df2015 = timesData[timesData.year==2015].iloc[:100,:]
df2016 = timesData[timesData.year==2016].iloc[:100,:]

# %%
trace1 = go.Scatter(
    x = df2014.world_rank,
    y = df2014.citations,
    mode = 'markers',
    name = '2014',
    marker = dict(color = 'rgba(16, 112, 2, 0.8)'),
    text = df.university_name
)

trace2 = go.Scatter(
    x=df2015.world_rank,
    y = df2015.citations,
    mode = 'markers',
  name = '2015',
  marker = dict(color = 'rgba(80, 26, 80, 0.8)'),
  text = df.university_name
)

trace3 = go.Scatter(
    x=df2016.world_rank,
    y = df2016.citations,
    mode = 'markers',
  name = '2016',
  marker = dict(color = 'rgba(0, 255, 80, 0.8)'),
  text = df.university_name
)

data = [trace1, trace2, trace3]

layout = dict(title = 'Cytowania i ranking najlepszych uczelni',
              xaxis = dict (title='Ranking swiatowy', ticklen =5, zeroline = False),
              yaxis = dict (title='cytowania', ticklen =5, zeroline = False))
fig=dict(data=data, layout=layout)
iplot (fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3b966612-e792-490d-aa6d-7c3f1705debd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3b966612-e792-490d-aa6d-7c3f1705debd")) {
#                     Plotly.newPlot(
#                         '3b966612-e792-490d-aa6d-7c3f1705debd',
# ...

# %%
df2014 = timesData[timesData.year==2014].iloc[:3,:]
df2015 = timesData[timesData.year==2015].iloc[:3,:]
df2016 = timesData[timesData.year==2016].iloc[:3,:]

# %%
trace1 = go.Bar(
      x = df2014.university_name,
      y = df2014.citations,
    name = 'Cytowania',
    marker = dict(color = 'rgba(80, 26, 80, 0.8)'), line=dict(color = 'rgba(0, 0, 0)', width=1.5)),
    text = df2014.university_name
)

trace2 = go.Bar(
    x=df2014.world_rank,
    y = df2014.teaching,
  name = 'Poziom nauki',
  marker = dict(color = 'rgba(80, 26, 80, 0.8)'), line=dict(color = 'rgba(0, 0, 0)', width=1.5)),
  text = df2014.university_name
)

data = [trace1, trace2]

layout = dict(title = 'Poziom nauczania i cytowania',
              xaxis = dict (title='Ranking swiatowy', ticklen =5, zeroline = False))
fig=dict(data=data, layout=layout)
iplot (fig)
# Out:
#   File "<ipython-input-88-664e6b31d02e>", line 6
#     text = df2014.university_name
#     ^
# IndentationError: unexpected indent

# %%
df2016 = timesData[timesData.year==2016].iloc[:7,:]

# %%
pie1 = df2016.num_students

# %%
pie1
# Out:
# 1803     2,243
# 1804    19,919
# 1805    15,596
# 1806    18,812
# 1807    11,074
# 1808    20,152
# 1809     7,929
# Name: num_students, dtype: object

# %%
pie1_list = [float(each.replace(',','.'))for each in df2016.num_students]

# %%
pie1_list
# Out:
# [2.243, 19.919, 15.596, 18.812, 11.074, 20.152, 7.929]

# %%
labels = df2016.university_name

# %%
fig ={
    'data' : [
            {
                'values':pie1_list,
                'labels':labels,
                'domain':{'x':[0,0.5]},
                'name' : 'liczba studentów (procentowo)',
                'hoverinfo':"label+percent+name",
                'hole' : .3,
                'type':'pie'
            },
    ],
    'layout':{
                'title':'Procentowa liczebność studentów na uniwersytetach',
                'annotations': [
                               {'font': {'size':20},
                                'showarrow' : False,
                                'text':'Liczba studentów',
                                'x': 0.2,
                                'y': 1 
                                },
                ]
    }
}

iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="310b6496-bc36-4598-93a9-5a9a951e3723" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("310b6496-bc36-4598-93a9-5a9a951e3723")) {
#                     Plotly.newPlot(
#                         '310b6496-bc36-4598-93a9-5a9a951e3723',
# ...

# %%
df2016 = timesData[timesData.year==2016].iloc[:20,:]
num_students_size = [float(each.replace(',','.'))for each in df2016.num_students]
international_color = [float(each) for each in df2016.international]

# %%
data = [
        {
            'y':df2016.teaching,
            'x':df2016.world_rank,
            'mode':'markers',
            'marker':{
                'color':international_color,
                'size':num_students_size,
                'showscale':True
            },
            'text':df2016.university_name
        }
]

iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d934ead1-3324-4473-a4c4-fbbadfb831a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d934ead1-3324-4473-a4c4-fbbadfb831a5")) {
#                     Plotly.newPlot(
#                         'd934ead1-3324-4473-a4c4-fbbadfb831a5',
# ...

# %%
x2011 = timesData.student_staff_ratio[timesData.year == 2011]
x2012 = timesData.student_staff_ratio[timesData.year == 2012]

# %%
trace1 = go.Histogram(
    x = x2011,
    opacity = 0.75,
    name = '2011',
    marker = dict(color='rgba(171, 50, 96, 0.6)')
)
trace2 = go.Histogram(
    x = x2012,
    opacity = 0.75,
    name = '2012',
    marker = dict(color='rgba(12, 50, 196, 0.6)')
)
data = [trace1, trace2]
layout = go.Layout(
    barmode = 'overlay',
    title = 'Stosunek liczby studentów do pracowników',
    xaxis = dict(title='Liczba studentów a pracowników'),
    yaxis=dict(title='liczba uniwersytetów')
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="25660430-ab40-46a7-ac1d-65f2cad10641" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("25660430-ab40-46a7-ac1d-65f2cad10641")) {
#                     Plotly.newPlot(
#                         '25660430-ab40-46a7-ac1d-65f2cad10641',
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
x2011 = timesData.country[timesData.year == 2011]
plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
    background_color = 'White',
    width = 512,
    height = 384
).generate(''.join(x2011))
plt.imshow(wordcloud)
plt.axis('off')

plt.show()

# %%
x2015 = timesData[timesData.year == 2015]

# %%
trace0=go.Box(
    y=x2015.total_score,
    name = 'wyniki uniwersytetów 2015',
    marker = dict(color = 'rgb(12,12,40)'),
)
trace1=go.Box(
    y=x2015.research,
    name = 'badania uniwersytetów 2015',
    marker = dict(color = 'rgb(12,128,128)'),
)

data = [trace0, trace1]
iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="649927a8-b1ac-4cc2-9fe6-96b4003991c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("649927a8-b1ac-4cc2-9fe6-96b4003991c4")) {
#                     Plotly.newPlot(
#                         '649927a8-b1ac-4cc2-9fe6-96b4003991c4',
# ...

# %%
import numpy as np
import plotly.figure_factory as ff

# %%
df = timesData[timesData.year == 2015]
data2015 = df.loc[:, ['research', 'international', 'total_score']]

data2015["index"] = np.arange(1, len(data2015)+1)

fig = ff.create_scatterplotmatrix(data2015, diag='box', index='index', colormap='Portland',
                                  colormap_type='cat',
                                  height=700, width=700)

iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4076876a-408a-499a-8e94-e54460ecf996" class="plotly-graph-div" style="height:700px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4076876a-408a-499a-8e94-e54460ecf996")) {
#                     Plotly.newPlot(
#                         '4076876a-408a-499a-8e94-e54460ecf996',
# ...

# %%
trace1 = go.Scatter3d(
    x=df.world_rank,
    y=df.research,
    z=df.citations,
    mode='markers',
    marker=dict(
        size=10,
        color= 'rgb(255,0,0)'
    )
)
data= [trace1]
layout=go.layout(
    margin = dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)

fig-go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-add48200f28f> in <module>()
#      15         r=0,
#      16         b=0,
# ---> 17         t=0
#      18     )
#      19 )
#
# TypeError: 'module' object is not callable

# %%
trace1 = go.Scatter3d(
    x=df.world_rank,
    y=df.research,
    z=df.citations,
    mode='markers',
    marker=dict(
        size=10,
        color = 'rgb(255,0,0)'
    )
)
data=[trace1]
layout = go.Layout(
    margin = dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6ad030c3-5e75-42bd-8ea0-dbed040dcc69" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6ad030c3-5e75-42bd-8ea0-dbed040dcc69")) {
#                     Plotly.newPlot(
#                         '6ad030c3-5e75-42bd-8ea0-dbed040dcc69',
# ...
